# %% [markdown]
# # Zero field splitting and dipolar connection test
#
# Notebook checks that the zero-field spitting of the tripelt molecule is connected to the dipolar interaction of pair correctly

# %%
import sys
import os

sys.path.append(os.path.abspath('D:\ITC\РНФ_Курганский_2024\pythonProject\MaRs'))

import numpy as np
import torch
from torch import nn
import math
import pathlib

from scipy.spatial import Delaunay
import matplotlib.pyplot as plt
from importlib import reload
import pandas as pd

import mars
from mars import spin_model
from mars import save_procedures

from mars import particles, spin_model, spectra_manager
from mars import optimization
# Out:
# Some stuff might fail: issue in joblib
# [KeOps] Warning : No C++ compiler found. Define CXX environment variable or install g++.
# [KeOps] Warning : No C++ compiler found. You need to either define the CXX environment variable pointing to a valid compiler, or ensure that 'g++' is installed and in your PATH.
# [KeOps] Warning : CUDA libraries not found or could not be loaded; Switching to CPU only.
# [KeOps] Warning : No C++ compiler found. You need to either define the CXX environment variable pointing to a valid compiler, or ensure that 'g++' is installed and in your PATH.
# [KeOps] Warning : No C++ compiler available to check for OpenMP support.
# [KeOps] Warning : OpenMP support is not available. Disabling OpenMP.

# %%
dtype = torch.float64
device = torch.device("cpu")
b1_field = 1.0 * 1e-6
freq = 9.67 * 1e9

# %%
def get_sample_triplet(params, dtype: torch.dtype = torch.float32, device: torch.device = torch.device("cpu")) ->\
        spin_model.SolidSample:
    g_factor, D, E, h_strain, gauss, lorentz =\
        params["g_factor"], params["D"], params["E"], params["h_strain"], params["gauss"], params["lorentz"]

    zeem = spin_model.Interaction(g_factor, dtype=dtype, device=device)

    D_val = D
    E_val = E

    ee_int = spin_model.DEInteraction((D_val, E_val), dtype=dtype, device=device)

    system = spin_model.SpinSystem(
        electrons=[1.0],
        g_tensors=[zeem],
        electron_electron=[(0, 0, ee_int)],
        dtype=dtype, device=device
    )
    return spin_model.SolidSample(system, h_strain, gauss, lorentz, mesh=(15, 15), dtype=dtype, device=device)

def get_sample_dipolar(params, dtype: torch.dtype = torch.float32, device: torch.device = torch.device("cpu")) ->\
        spin_model.SolidSample:
    g_factor, D, E, h_strain, gauss, lorentz =\
        params["g_factor"], params["D"], params["E"], params["h_strain"], params["gauss"], params["lorentz"]

    zeem = spin_model.Interaction(g_factor, dtype=dtype, device=device)

    D_val = 2.0 * D
    E_val = 2.0 * E

    J = -1.1
    J = -2 * J
    J_hz = mars.constants.unit_converter(J, "cm-1_to_Hz")

    ee_int = spin_model.DEInteraction((D_val, E_val), dtype=dtype, device=device) +\
        spin_model.Interaction(J_hz, dtype=dtype, device=device)

    system = spin_model.SpinSystem(
        electrons=[0.5, 0.5],
        g_tensors=[zeem, zeem],
        electron_electron=[(0, 1, ee_int)],
        dtype=dtype, device=device
    )
    return spin_model.SolidSample(system, h_strain, gauss, lorentz, mesh=(15, 15), dtype=dtype, device=device)

def _get_density_fanction(device, dtype):
    # Reference parameters
    J_k_val = mars.constants.unit_converter(9.6 * 1e9, "Hz_to_cm-1")
    J_k = torch.as_tensor(J_k_val, device=device, dtype=dtype)
    T_ref = torch.as_tensor(4.0, device=device, dtype=dtype)

    x_ref = J_k / (2.0 * T_ref)
    A_K = (J_k ** 3) / torch.tanh(x_ref)  # Sum of emission + absorption at reference

    #A_K = (J_k ** 3)

    def _density_function(omega, temperature):
        """
        Normalized spectral density for direct phonon process.
        Returns J(omega)/A_K where J(omega) + J(-omega) = 1 at (2.2 cm^-1, 4 K).

        omega : signed transition frequency in rad/s
                > 0 : Direct (emission)
                < 0 : Reverse (absorption)
        """
        omega_hz = omega / (2.0 * math.pi)
        omega_K = mars.constants.unit_converter(omega_hz, "Hz_to_K")
        T = torch.as_tensor(temperature, device=device, dtype=dtype)

        T_safe = torch.clamp(T, min=1e-12)
        abs_omega = torch.abs(omega_K)
        is_zero = abs_omega < 1e-12  # Exact zero guard

        x = abs_omega / (2.0 * T_safe)

        denom = torch.expm1(2.0 * x)
        n = torch.where(x < 1e-4, 1.0 / (2.0 * x), 1.0 / denom)

        factor = torch.where(
            omega_K > 0, n + 1.0,
            torch.where(omega_K < 0, n, torch.zeros_like(x))
        )

        density = (abs_omega ** 3) * factor
        density = torch.where(is_zero, torch.zeros_like(density), density)
        print((density / A_K)[0, 0])
        # Normalize to reference sum
        return density / A_K

    return _density_function

# %%
params = {'g_factor': 2.0062566367854773,
 'D': 90217300.40595116,
 'E': 30083617.12040935,
 'lorentz': 0.0007068854625226938,
  'gauss': 0.0,
 'h_strain': 29094138.27713324}
sample_dirad = get_sample_dipolar(params, dtype=dtype, device=device)
sample_triplet = get_sample_triplet(params, dtype=dtype, device=device)

# %% [markdown]
# ### Check that ZFS and Dipolar give the same relaxation dependacne. But with the difference scale

# %%
dipolar = mars.spin_model.DEInteraction([0.0, 1.0], device=device, dtype=dtype).tensor
zfs = mars.spin_model.DEInteraction([0.0, 1.0], device=device, dtype=dtype).tensor

_density_function = _get_density_fanction(device, dtype)

dipolar = sample_dirad.get_oriented_electron_electron_interaction(dipolar, 0, 1)
zfs = sample_triplet.get_oriented_electron_electron_interaction(zfs, 0, 0)

# %%
dipolar = [(dipolar, torch.zeros_like(dipolar))]
zfs = [(zfs, torch.zeros_like(zfs))]

# %%
red_channel_dipolar = mars.population.RedfieldRelaxationChannel(
        dipolar, _density_function, thermal_balance_mode="symmetric")
red_channel_zfs = mars.population.RedfieldRelaxationChannel(
        zfs, _density_function, thermal_balance_mode="symmetric")

# %%
red_channel_zfs
# Out:
# RedfieldRelaxationChannel(
# thermal_balance_mode=Not Initialized,
# secular=False,
# eigen_basis=None,
# num_operators=1,
# spectral_density_func=_density_function)

# %%
context_zfs = mars.population.Context(basis="product",
    sample=sample_triplet, relaxation_coupling_channels=[red_channel_zfs], device=device, dtype=dtype
)
context_dirad = mars.population.Context(basis="product",
    sample=sample_dirad, relaxation_coupling_channels=[red_channel_dipolar], device=device, dtype=dtype
)

# %%
T1_fields = torch.linspace(0.25, 0.4, 1000, dtype=dtype, device=device)
res_fields, kinetic_coeffs = mars.visualization.analysis.relaxation_field_dep(context_dirad, sample_dirad, freq=freq, temperature=4.0, fields=T1_fields, levels_pair=(1, 3), )
plt.scatter(res_fields.flatten(), kinetic_coeffs.flatten())
# Out:
# tensor([[ 0.0000, 48.7876, 70.5184, 98.0357],
#         [24.8509,  0.0000,  1.1117,  4.7976],
#         [31.9850,  0.9899,  0.0000,  1.1548],
#         [39.5094,  3.7959,  1.0261,  0.0000]], dtype=torch.float64)

# %%
T1_fields = torch.linspace(0.25, 0.4, 1000, dtype=dtype, device=device)
res_fields, kinetic_coeffs = mars.visualization.analysis.relaxation_field_dep(context_zfs, sample_triplet, freq=freq, temperature=4.0, fields=T1_fields, levels_pair=(0, 2), )
plt.scatter(res_fields.flatten(), kinetic_coeffs.flatten())
# Out:
# tensor([[0.0000, 1.1117, 4.7976],
#         [0.9899, 0.0000, 1.1548],
#         [3.7959, 1.0261, 0.0000]], dtype=torch.float64)

# %% [markdown]
# The plots differ in 4 times. Because the ZFS and dipolar tensors in general differ in 2 times and the relaxation ~ |A|^2
