# %% [markdown]
# # Comprehensive Quality Assurance & Regression Tests
#
# Serves as a systematic QA suite for spectrum generation across diverse spin Hamiltonians. It tests numerical stability and correctness for various spin multiplicities, anisotropic interactions (g-tensors, ZFS, hyperfine, exchange, dipolar), and computational configurations (mesh types, integration methods, and relaxation models) to ensure robust library behavior.

# %%
# %load_ext autoreload
# %autoreload 2
import sys
import os
import math
from importlib import reload

import torch
from torch import nn
import numpy as np
import matplotlib.pyplot as plt

sys.path.append(os.path.abspath(os.path.join(os.getcwd(), '..', '..')))

import mars

import pandas as pd

# %%
dtype = torch.float64

# %%
def read_csv(name: str):
    df = pd.read_csv(f".\easy_spin_checked\{name}.csv", names=["fields", "spectrum"]).to_numpy()
    return df[:, 0], df[:, 1]

# %% [markdown]
# ### System_1

# %%
name = "spectra_1"

g_interaction = mars.spin_model.Interaction(2.1, dtype=dtype)
DE_interaction = mars.spin_model.DEInteraction([1e6 * 1e6, 1e3 * 1e6], dtype=dtype)
freq = 38.0 * 1e9
gauss = 1e-2
lorentz = 1e-2
ham_strain = 2 * 1e9
temp = 3.5

spin_system = mars.spin_model.SpinSystem(
    electrons=[3/2],
    g_tensors=[g_interaction],
    electron_electron=[(0, 0, DE_interaction)],
    dtype=dtype,
)

sample = mars.spin_model.MultiOrientedSample(
    base_spin_system=spin_system,
    gauss=gauss,
    lorentz=lorentz,
    ham_strain=ham_strain,
    dtype=dtype,
    mesh=(20, 40)
)
computational_details = mars.spectra_manager.ComputationalDetails(res_field_r_tol=1e-5)

spectra_creator = mars.spectra_manager.StationarySpectra(
    computational_details=computational_details,
    sample=sample,
    freq=freq,
    temperature=temp,
    dtype=dtype,
)
fields = torch.linspace(0.0, 1.5, 1000, dtype=dtype)
spectrum = spectra_creator(sample, fields=fields)

spectrum = spectrum / torch.max(torch.abs(spectrum))
plt.plot(fields, spectrum, "-", label="Current computation")

fields, easy_spin_out = read_csv(name)
easy_spin_out = easy_spin_out / np.max(np.abs(easy_spin_out))
plt.plot(fields, easy_spin_out, "--", label="Easy spin checked")
plt.xlabel("Field (T)")
plt.legend()
plt.title(f"{name}")
# Out:
# Text(0.5, 1.0, 'spectra_1')

# %%
#mars.save(".\example_parameters.mat", sample=sample, spectra_creator=spectra_creator, field=fields, format_type="easyspin")

#import pandas as pd
#data_frame = pd.DataFrame({"field": fields, "spec": spectrum})
#data_frame.to_csv(f".\easy_spin_checked\{name}.csv", header=False, index=False)

# %% [markdown]
# ### System_2

# %%
name = "spectra_2"

g_1_interaction = mars.spin_model.Interaction([2.1, 2.2, 2.3], dtype=dtype)
g_2_interaction = mars.spin_model.Interaction(2.1, dtype=dtype)

dipolar_interaction = mars.spin_model.DEInteraction([1e6 * 1e3, 0.0], dtype=dtype)
DE_interaction = mars.spin_model.DEInteraction([1e6 * 1e3, 0.0], dtype=dtype)

freq = 38.0 * 1e9
gauss = 1e-2
lorentz = 1e-2
ham_strain = 2 * 1e6 * 100
temp = 100

spin_system = mars.spin_model.SpinSystem(
    electrons=[1/2, 3/2],
    g_tensors=[g_1_interaction, g_2_interaction],
    electron_electron=[(1, 1, DE_interaction), (0, 1, dipolar_interaction)],
    dtype=dtype,
)

mesh = mars.mesher.DelaunayMesh(initial_grid_frequency=20, interpolation_grid_frequency=40, interpolate=True, dtype=dtype)

sample = mars.spin_model.MultiOrientedSample(
    base_spin_system=spin_system,
    gauss=gauss,
    lorentz=lorentz,
    ham_strain=ham_strain,
    dtype=dtype,
    mesh=mesh
)


spectra_creator = mars.spectra_manager.StationarySpectra(
    sample=sample,
    freq=freq,
    temperature=temp,
    dtype=dtype,
)

fields = torch.linspace(1.1, 1.4, 1000, dtype=dtype)
spectrum = spectra_creator(sample, fields=fields)

spectrum = spectrum / torch.max(torch.abs(spectrum))
plt.plot(fields, spectrum, "-", label="Current computation")

fields, easy_spin_out = read_csv(name)
easy_spin_out = easy_spin_out / np.max(np.abs(easy_spin_out))
plt.plot(fields, easy_spin_out, "--", label="Easy spin checked")

plt.xlabel("Field (T)")
plt.legend()
plt.title(f"{name}")
# Out:
# Text(0.5, 1.0, 'spectra_2')

# %%
#mars.save(".\example_parameters.mat", sample=sample, spectra_creator=spectra_creator, field=fields, format_type="easyspin")

#import pandas as pd
#data_frame = pd.DataFrame({"field": fields, "spec": spectrum})
#data_frame.to_csv(f".\easy_spin_checked\{name}.csv", header=False, index=False)

# %% [markdown]
# ### System_3

# %%
name = "spectra_3"

g_1_interaction = mars.spin_model.Interaction([2.1, 2.2, 2.3], dtype=dtype)
g_2_interaction = mars.spin_model.Interaction([2.1, 2.2, 2.3], dtype=dtype, frame=[1.0, 1.0, 1.0])

J_interaction = mars.spin_model.Interaction(mars.constants.unit_converter(2 * 5, "cm-1_to_Hz"), dtype=dtype)
DE_interaction = mars.spin_model.DEInteraction([3 * 1e6 * 1e3, 0.0], dtype=dtype)

freq = 38.0 * 1e9
gauss = 1e-2
lorentz = 1e-2
ham_strain = 0.0
temp = 100

spin_system = mars.spin_model.SpinSystem(
    electrons=[1/2, 2.0/2],
    g_tensors=[g_1_interaction, g_2_interaction],
    electron_electron=[(1, 1, DE_interaction), (0, 1, J_interaction)],
    dtype=dtype,
)

sample = mars.spin_model.MultiOrientedSample(
    base_spin_system=spin_system,
    gauss=gauss,
    lorentz=lorentz,
    ham_strain=ham_strain,
    dtype=dtype,
    mesh=(20, 40)
)


spectra_creator = mars.spectra_manager.StationarySpectra(
    sample=sample,
    freq=freq,
    temperature=temp,
    dtype=dtype,
)

fields = torch.linspace(1.0, 1.5, 1000, dtype=dtype)
spectrum = spectra_creator(sample, fields=fields)

spectrum = spectrum / torch.max(torch.abs(spectrum))
plt.plot(fields, spectrum, "-", label="Current computation")

fields, easy_spin_out = read_csv(name)
easy_spin_out = easy_spin_out / np.max(np.abs(easy_spin_out))
plt.plot(fields, easy_spin_out, "--", label="Easy spin checked")

plt.xlabel("Field (T)")
plt.legend()
plt.title(f"{name}")
# Out:
# Text(0.5, 1.0, 'spectra_3')

# %%
#mars.save(".\example_parameters.mat", sample=sample, spectra_creator=spectra_creator, field=fields, format_type="easyspin")

#import pandas as pd
#data_frame = pd.DataFrame({"field": fields, "spec": spectrum})
#data_frame.to_csv(f".\easy_spin_checked\{name}.csv", header=False, index=False)

# %% [markdown]
# ### System_4

# %%
name = "spectra_4"

g_1_interaction = mars.spin_model.Interaction([2.1, 2.2, 2.3], dtype=dtype)
g_2_interaction = mars.spin_model.Interaction([2.1, 2.2, 2.3], dtype=dtype)

J_interaction = mars.spin_model.Interaction(mars.constants.unit_converter(-6, "cm-1_to_Hz"), dtype=dtype)
DE_interaction = mars.spin_model.DEInteraction([5.99 * 1e3 * 1e6, 0.89 * 1e3 * 1e6], dtype=dtype)

freq = 38.0 * 1e9
gauss = 1e-2
lorentz = 1e-2
ham_strain = 0.0
temp = 3.5

spin_system = mars.spin_model.SpinSystem(
    electrons=[1/2, 1.0/1.0],
    g_tensors=[g_1_interaction, g_2_interaction],
    electron_electron=[(1, 1, DE_interaction), (0, 1, J_interaction)],
    dtype=dtype,
)

sample = mars.spin_model.MultiOrientedSample(
    base_spin_system=spin_system,
    gauss=gauss,
    lorentz=lorentz,
    ham_strain=ham_strain,
    dtype=dtype,
    mesh=(20, 40)
)


spectra_creator = mars.spectra_manager.StationarySpectra(
    sample=sample,
    freq=freq,
    temperature=temp,
    dtype=dtype,
)

fields = torch.linspace(0.96, 1.5, 3000, dtype=dtype)
spectrum = spectra_creator(sample, fields=fields)

spectrum = spectrum / torch.max(torch.abs(spectrum))
plt.plot(fields, spectrum, "-", label="Current computation")

fields, easy_spin_out = read_csv(name)
easy_spin_out = easy_spin_out / np.max(np.abs(easy_spin_out))
plt.plot(fields, easy_spin_out, "--", label="Easy spin checked")

plt.xlabel("Field (T)")
plt.legend()
plt.title(f"{name}")
# Out:
# Text(0.5, 1.0, 'spectra_4')

# %%
# mars.save(".\example_parameters.mat", sample=sample, spectra_creator=spectra_creator, field=fields, format_type="easyspin")

#import pandas as pd
#data_frame = pd.DataFrame({"field": fields, "spec": spectrum})
#data_frame.to_csv(f".\easy_spin_checked\{name}.csv", header=False, index=False)

# %% [markdown]
# ### System_5

# %%
name = "spectra_5"

g_interaction = mars.spin_model.Interaction([2.12, 2.02, 2.30], dtype=dtype)


freq = 9.81 * 1e9
gauss = 0.0
lorentz = 0.0
ham_strain = torch.tensor([100, 100, 1e3], dtype=dtype) * 1e6
temp = 293

spin_system = mars.spin_model.SpinSystem(
    electrons=[1/2],
    g_tensors=[g_interaction],
    dtype=dtype,
)

sample = mars.spin_model.MultiOrientedSample(
    base_spin_system=spin_system,
    gauss=gauss,
    lorentz=lorentz,
    ham_strain=ham_strain,
    dtype=dtype,
    mesh=(20,40)
)


spectra_creator = mars.spectra_manager.StationarySpectra(
    sample=sample,
    freq=freq,
    temperature=temp,
    dtype=dtype,
)

fields = torch.linspace(0.2, 0.45, 1000, dtype=dtype)
spectrum = spectra_creator(sample, fields=fields)

spectrum = spectrum / torch.max(torch.abs(spectrum))
plt.plot(fields, spectrum, "-", label="Current computation")

fields, easy_spin_out = read_csv(name)
easy_spin_out = easy_spin_out / np.max(np.abs(easy_spin_out))
plt.plot(fields, easy_spin_out, "--", label="Easy spin checked")

plt.xlabel("Field (T)")
plt.legend()
plt.title(f"{name}")
# Out:
# Text(0.5, 1.0, 'spectra_5')

# %%
#mars.save(".\example_parameters.mat", sample=sample, spectra_creator=spectra_creator, field=fields, format_type="easyspin")

#import pandas as pd
#data_frame = pd.DataFrame({"field": fields, "spec": spectrum})
#data_frame.to_csv(f".\easy_spin_checked\{name}.csv", header=False, index=False)

# %% [markdown]
# ### System_6

# %%
name = "spectra_6"

g_interaction = mars.spin_model.Interaction([2.1, 2.2, 2.3], dtype=dtype)
hyperfine_interaction = mars.spin_model.Interaction([10 * 1e6, 10 * 1e6, 1e3 * 1e6], dtype=dtype)

freq = 38.0 * 1e9
gauss = 5e-3
lorentz = 5e-3
ham_strain = 0.0
temp = 293

spin_system = mars.spin_model.SpinSystem(
    electrons=[1/2],
    nuclei=["14N", "14N"],
    g_tensors=[g_interaction],
    electron_nuclei=[(0, 0, hyperfine_interaction), (0, 1, hyperfine_interaction)],
    dtype=dtype,
)

sample = mars.spin_model.MultiOrientedSample(
    base_spin_system=spin_system,
    gauss=gauss,
    lorentz=lorentz,
    ham_strain=ham_strain,
    dtype=dtype,
    mesh=(20,40)
)


spectra_creator = mars.spectra_manager.StationarySpectra(
    sample=sample,
    freq=freq,
    temperature=temp,
    dtype=dtype,
)

fields = torch.linspace(1.0, 1.4, 1500, dtype=dtype)
spectrum = spectra_creator(sample, fields=fields)

spectrum = spectrum / torch.max(torch.abs(spectrum))
plt.plot(fields, spectrum, "-", label="Current computation")

fields, easy_spin_out = read_csv(name)
easy_spin_out = easy_spin_out / np.max(np.abs(easy_spin_out))
plt.plot(fields, easy_spin_out, "--", label="Easy spin checked")

plt.xlabel("Field (T)")
plt.legend()
plt.title(f"{name}")
# Out:
# Text(0.5, 1.0, 'spectra_6')

# %%
#mars.save(".\example_parameters.mat", sample=sample, spectra_creator=spectra_creator, field=fields, format_type="easyspin")

#import pandas as pd
#data_frame = pd.DataFrame({"field": fields, "spec": spectrum})
#data_frame.to_csv(f".\easy_spin_checked\{name}.csv", header=False, index=False)

# %% [markdown]
# ### System_7

# %%
name = "spectra_7"

g_interaction = mars.spin_model.Interaction([2.0, 2.1, 2.2], dtype=dtype)
hyperfine_interaction = mars.spin_model.Interaction([100.0 * 1e6, 100 * 1e6, 1e3 * 1e6], dtype=dtype)
DE_interaction = mars.spin_model.DEInteraction([-1.0e8, 0.0], dtype=dtype)


freq = 38.0 * 1e9
gauss = 5e-3
lorentz = 5e-3
ham_strain = 0.0
temp = 3.5

spin_system = mars.spin_model.SpinSystem(
    electrons=[5/2],
    nuclei=["55Mn"],
    g_tensors=[g_interaction],
    electron_electron=[(0, 0, DE_interaction)],
    electron_nuclei=[(0, 0, hyperfine_interaction)],
    dtype=dtype,
)

sample = mars.spin_model.MultiOrientedSample(
    base_spin_system=spin_system,
    gauss=gauss,
    lorentz=lorentz,
    ham_strain=ham_strain,
    dtype=dtype,
    mesh=(25, 25)
)


spectra_creator = mars.spectra_manager.StationarySpectra(
    sample=sample,
    freq=freq,
    temperature=temp,
    dtype=dtype,
)

fields = torch.linspace(1.0, 1.5, 2000, dtype=dtype)
spectrum = spectra_creator(sample, fields=fields)

spectrum = spectrum / torch.max(torch.abs(spectrum))
plt.plot(fields, spectrum, "-", label="Current computation")

fields, easy_spin_out = read_csv(name)
easy_spin_out = easy_spin_out / np.max(np.abs(easy_spin_out))
plt.plot(fields, easy_spin_out, "--", label="Easy spin checked")

plt.xlabel("Field (T)")
plt.legend()
plt.title(f"{name}")
# Out:
# Text(0.5, 1.0, 'spectra_7')

# %%
#mars.save(".\example_parameters.mat", sample=sample, spectra_creator=spectra_creator, field=fields, format_type="easyspin")

#import pandas as pd
#data_frame = pd.DataFrame({"field": fields, "spec": spectrum})
#data_frame.to_csv(f".\easy_spin_checked\{name}.csv", header=False, index=False)

# %% [markdown]
# ### System 8

# %%
name = "spectra_8"

g_interaction = mars.spin_model.Interaction([2.0, 2.06, 2.2], dtype=dtype)
DE_interaction = mars.spin_model.DEInteraction([1e10, 0.0], dtype=dtype)


freq = 38.0 * 1e9
gauss = 5e-3
lorentz = 5e-3
ham_strain = 1e7
temp = 293.0

spin_system = mars.spin_model.SpinSystem(
    electrons=[3/2],
    g_tensors=[g_interaction],
    electron_electron=[(0, 0, DE_interaction)],
    dtype=dtype,
)

sample = mars.spin_model.MultiOrientedSample(
    base_spin_system=spin_system,
    gauss=gauss,
    lorentz=lorentz,
    ham_strain=ham_strain,
    dtype=dtype,
    mesh=(20, 40)
)


spectra_creator = mars.spectra_manager.StationarySpectra(
    sample=sample,
    freq=freq,
    temperature=temp,
    dtype=dtype,
)

fields = torch.linspace(0.0, 2.1, 2000, dtype=dtype)
spectrum = spectra_creator(sample, fields=fields)

spectrum = spectrum / torch.max(torch.abs(spectrum))
plt.plot(fields, spectrum, "-", label="Current computation")

fields, easy_spin_out = read_csv(name)
easy_spin_out = easy_spin_out / np.max(np.abs(easy_spin_out))
plt.plot(fields, easy_spin_out, "--", label="Easy spin checked")

plt.xlabel("Field (T)")
plt.legend()
plt.title(f"{name}")
# Out:
# D:\ITC\РНФ_Курганский_2024\pythonProject\MarS\mars\spectra_manager\res_line_solvers\res_field_algorithm.py:234: UserWarning: The degenerated or near-degenerated levels were found.Convergence may be incorrect.Increase the spatial grid and decrease the res_field_r_tol if necessary.
#   warnings.warn("The degenerated or near-degenerated levels were found."
# Text(0.5, 1.0, 'spectra_8')

# %%
mars.save(".\example_parameters.mat", sample=sample, spectra_creator=spectra_creator, field=fields, format_type="easyspin")

#import pandas as pd
#data_frame = pd.DataFrame({"field": fields, "spec": spectrum})
#data_frame.to_csv(f".\easy_spin_checked\{name}.csv", header=False, index=False)

# %% [markdown]
# ### System 9

# %%
name = "spectra_9"

g_interaction = mars.spin_model.Interaction(2.1, dtype=dtype)
DE_interaction = mars.spin_model.DEInteraction([1e6 * 1e6, 1e3 * 1e6], dtype=dtype)
freq = 38.0 * 1e9
gauss = 1e-2
lorentz = 1e-2
ham_strain = 2 * 1e9
temp = 3.5

spin_system = mars.spin_model.SpinSystem(
    electrons=[3/2],
    g_tensors=[g_interaction],
    electron_electron=[(0, 0, DE_interaction)],
    dtype=dtype,
)

sample = mars.spin_model.MultiOrientedSample(
    base_spin_system=spin_system,
    gauss=gauss,
    lorentz=lorentz,
    ham_strain=ham_strain,
    dtype=dtype,
    mesh=(20, 40)
)


spectra_creator = mars.spectra_manager.StationarySpectra(
    harmonic=0,
    sample=sample,
    freq=freq,
    temperature=temp,
    dtype=dtype,
)

fields = torch.linspace(0.0, 1.5, 1000, dtype=dtype)
spectrum = spectra_creator(sample, fields=fields)


spectrum = spectrum / torch.max(torch.abs(spectrum))
plt.plot(fields, spectrum, "-", label="Current computation")

fields, easy_spin_out = read_csv(name)
easy_spin_out = easy_spin_out / np.max(np.abs(easy_spin_out))
plt.plot(fields, easy_spin_out, "--", label="Easy spin checked")

plt.xlabel("Field (T)")
plt.legend()
plt.title(f"{name}")
# Out:
# Text(0.5, 1.0, 'spectra_9')

# %% [markdown]
# ### Computattional details check

# %%
name = "spectra_9"

g_interaction = mars.spin_model.Interaction(2.1, dtype=dtype)
DE_interaction = mars.spin_model.DEInteraction([1e6 * 1e6, 1e3 * 1e6], dtype=dtype)
freq = 38.0 * 1e9
gauss = 1e-2
lorentz = 1e-2
ham_strain = 2 * 1e9
temp = 3.5

spin_system = mars.spin_model.SpinSystem(
    electrons=[3/2],
    g_tensors=[g_interaction],
    electron_electron=[(0, 0, DE_interaction)],
    dtype=dtype,
)

mesh = mars.mesher.AxialMesh(initial_grid_frequency=23, interpolation_grid_frequency=40, dtype=dtype)

sample = mars.spin_model.MultiOrientedSample(
    base_spin_system=spin_system,
    gauss=gauss,
    lorentz=lorentz,
    ham_strain=ham_strain,
    dtype=dtype,
    mesh=mesh
)

computational_details = mars.spectra_manager.ComputationalDetails(integration_computation_method="analytical")

spectra_creator = mars.spectra_manager.StationarySpectra(
    sample=sample,
    harmonic=0,
    freq=freq,
    temperature=temp,
    computational_details=computational_details,
    dtype=dtype,
)

fields = torch.linspace(0.01, 1.5, 1000, dtype=dtype)
spectrum = spectra_creator(sample, fields=fields)


spectrum = spectrum / torch.max(torch.abs(spectrum))
plt.plot(fields, spectrum, "-", label="Current computation")

fields, easy_spin_out = read_csv(name)
easy_spin_out = easy_spin_out / np.max(np.abs(easy_spin_out))
plt.plot(fields, easy_spin_out, "--", label="Easy spin checked")


plt.xlabel("Field (T)")
plt.legend()
plt.title(f"{name}")
# Out:
# Text(0.5, 1.0, 'spectra_9')
